# %%
import sys
sys.version
# Out:
# '3.7.1 (default, Dec 10 2018, 22:54:23) [MSC v.1915 64 bit (AMD64)]'

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image, ImageOps
# %matplotlib inline

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 5E20-1D3C
#
#  Directory of C:\Users\acer\Documents\Image Pyhton
#
# 03/01/2019  10:28 PM    <DIR>          .
# 03/01/2019  10:28 PM    <DIR>          ..
# 01/06/2019  02:57 PM    <DIR>          .ipynb_checkpoints
# 03/01/2019  10:24 PM         1,206,247 bulldog.jpg
# 03/01/2019  10:25 PM           181,557 Graykecil.jpg
# 03/01/2019  10:27 PM             1,351 Grayscale, Resize, Save.ipynb
# 03/01/2019  10:27 PM           723,107 Histogram Numpy.ipynb
# 03/01/2019  10:28 PM           155,119 ship.jpg
#                5 File(s)      2,267,381 bytes
#                3 Dir(s)  17,665,527,808 bytes free

# %%
! ls
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
img = plt.imread('bulldog.jpg')
plt.imshow(img)

# %%
img.shape
# Out:
# (1301, 2000, 3)

# %%
img_pil = Image.fromarray(np.uint8(img))
img_pil = ImageOps.equalize(img_pil)
plt.imshow(img_pil)

# %%
img2 = np.asarray(img_pil)
plt.imshow(img2)

# %%
plt.hist(img.flatten())
# Out:
# (array([ 330626.,  615475.,  936082., 1036621., 1093662., 1058327.,
#          937570.,  704093.,  478750.,  614794.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(img2.flatten())
# Out:
# (array([ 765049.,  731322.,  781086.,  723034.,  760146.,  723842.,
#          765461.,  736025.,  753764., 1066271.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <a list of 10 Patch objects>)

# %%
np.save('bulls.jpg', img2)
